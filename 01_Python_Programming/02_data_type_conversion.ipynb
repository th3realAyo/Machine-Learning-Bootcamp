# %%
x = 10
print(x)
print(type(x))

# float(var) -> convert to float
x = float(x)
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>

# %%
y = 5.8
print(y)
print(type(y))

y = int(y)
print(y)
print(type(y))
# Out:
# 5.8
# <class 'float'>
# 5
# <class 'int'>

# %%
z = 15
print(z)
print(type(z))

z = str(z)
print(z)
print(type(z))
# Out:
# 15
# <class 'int'>
# 15
# <class 'str'>

# %%
a = 15
b = "15"

print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 15
# 15
# <class 'int'>
# <class 'str'>

# %%
a
# Out:
# 15

# %%
b
# Out:
# '15'

# %%
age = input("Enter your age: ")
print(age)
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(input("Enter your age: "))
print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %%
height = float(input("Enter your height: "))
print(height)
print(type(height))
# Out:
# 20.0
# <class 'float'>

# %%
# cannot convert these kind of strings to integers or float
x = "Alice"
x = int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # cannot convert these kind of strings to integers or float
#       2 x = "Alice"
# ----> 3 x = int(x)
#
# ValueError: invalid literal for int() with base 10: 'Alice'

# %%
y = "25"
y = int(y)
print(y)
print(type(y))
