# %% [markdown]
# **1. Basic if statement**

# %% [markdown]
# if condition is True:
#
#         then execute this code block

# %%
age = 15

# check if the person is 18 or older
if age >= 18:
    print("You are an adult!")

# %%
# Ask the user for their age
age = int(input("Enter your age: "))

# Check if the person is 18 or older
if age >= 18:
    print("You're an adult!")

# %% [markdown]
# **2. if and else**

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You can vote!")
else:
    print("Sorry, you are too young to vote")
# Out:
# Sorry, you are too young to vote

# %% [markdown]
# **3. if elif else**

# %% [markdown]
# elif -> else if

# %%
marks = int(input("Enter your score (out of 100): "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Grade D or below - keep learning")
# Out:
# Grade D or below - keep learning

# %% [markdown]
# **4. Nested if statements**

# %%
age = int(input("Enter your age: "))
has_id = input("Do you have an ID? (yes/no): ")

if age >= 18:
    if has_id == "yes":
        print("Entry allowed.")
    else:
        print("You need to show ID.")
else:
    print("You're not allowed. Must be 18 or older.")
# Out:
# Entry allowed.

# %% [markdown]
# **5. Combining conditions with and/or**

# %%
age = int(input("Enter your age: "))
has_ticket = input("Do you have a ticket? (yes/no): ")

if age >= 18 and has_ticket == "yes":
    print("Welcome to the concert!")
else:
    print("Sorry, you must be 18+ and have a ticket.")
# Out:
# Welcome to the concert!
