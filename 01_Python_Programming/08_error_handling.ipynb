# %% [markdown]
# **1. Simulate an error**

# %%
num = int(input("Enter a number: "))
print("You entered:", num)
# Out:
# You enetered: 20

# %%
num = int(input("Enter a number: "))
print("You entered:", num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num = int(input("Enter a number: "))
#       2 print("You enetered:", num)
#
# ValueError: invalid literal for int() with base 10: 'Sid'

# %% [markdown]
# **2. Using try and except block**

# %%
try:
    num = int(input("Enter a number: "))
    print("You enetered:", num)
except ValueError:
    print("Oops! That's not a valid number")
# Out:
# Oops! That's not a valid number

# %% [markdown]
# **3. Catching any errors**

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result is:", result)
except:
    print("Something went wrong")
# Out:
# Result is: 0.5

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result is:", result)
except Exception as e:
    print("Something went wrong:", str(e))
# Out:
# Something went wrong: invalid literal for int() with base 10: 'dd'

# %% [markdown]
# **4.Multiple except blocks**

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result is:", result)

except ValueError:
    print("Please enter a valid number.")

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Please enter a valid number.

# %% [markdown]
# **5. finally block**

# %%
try:
    num = int(input("Enter a number: "))
    print("Number is: ", num)
except:
    print("Something went wrong")
finally:
    print("This runs no matter what.")
# Out:
# Something went wrong
# This runs no matter what.
