# %%
# %pip install -q seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt
import warnings
from scipy.stats import pearsonr # type: ignore


warnings.filterwarnings("ignore")
np.random.seed(42)
pd.set_option("display.max_columns", 50)
sns.set_style("whitegrid")


def showlayout():
    plt.figure(figsize=(9, 4))
    plt.tight_layout()
    plt.show()

# %%
df = pd.read_csv( \
    r"C:\Users\AYO_AYO\Desktop\Machine-Learning-Bootcamp\CSV-Excel\Datasets\titanic_dataset.csv")

# %%
num_cols = df.select_dtypes([np.number]).columns.to_list()
cat_cols = [col for col in df.columns if col not in num_cols]

print(num_cols)
print(cat_cols)
# Out:
# ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']
# ['sex', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
df_nums = df[num_cols].dropna()
df_nums.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
df_nums["survived_label"] = df_nums["survived"].map({0:"No", 1:"Yes"})

# %% [markdown]
# ### Numerical v Numerical

# %% [markdown]
# **Scatter plot**

# %%
sns.scatterplot(x = df["age"], y=df["fare"])
plt.xlabel("Age")
plt.ylabel("Fare")
showlayout()

# %%
num_pairs = [
    ("age", "fare"),
    ("age", "sibsp"),
    ("fare", "sibsp")
]

for x, y in num_pairs:
    sns.scatterplot(data=df, x=x, y=y)
    plt.title(f"{x} vs {y}")
    plt.xlabel(x)
    plt.ylabel(y)
    showlayout()

# %% [markdown]
# **Correlation Matrix**

# %%
print("Correlation Matrix")
corr = df_nums.corr(numeric_only = True)
# Out:
# Correlation Matrix

# %%
df_nums
# Out:
#      survived  pclass   age  sibsp  parch     fare survived_label
# 0           0       3  22.0      1      0   7.2500             No
# 1           1       1  38.0      1      0  71.2833            Yes
# 2           1       3  26.0      0      0   7.9250            Yes
# 3           1       1  35.0      1      0  53.1000            Yes
# 4           0       3  35.0      0      0   8.0500             No
# ..        ...     ...   ...    ...    ...      ...            ...
# 885         0       3  39.0      0      5  29.1250             No
# 886         0       2  27.0      0      0  13.0000             No
# 887         1       1  19.0      0      0  30.0000            Yes
# 889         1       1  26.0      0      0  30.0000            Yes
# 890         0       3  32.0      0      0   7.7500             No
#
# [714 rows x 7 columns]

# %%
print("Pearson correlation with fare")

for _ in num_cols:
    if _ != "fare":
        r, p = pearsonr(df_nums[_], df_nums["fare"])
        print(f"{_} vs fare: r: {r:.3f}: p: {p:.3f}")
# Out:
# Pearson correlation with fare
# survived vs fare: r: 0.268: p: 0.000
# pclass vs fare: r: -0.554: p: 0.000
# age vs fare: r: 0.096: p: 0.010
# sibsp vs fare: r: 0.138: p: 0.000
# parch vs fare: r: 0.205: p: 0.000

# %% [markdown]
# **Numerical vs Category**

# %%
num_for_box = ["age", "fare"]
cat_for_box = ["survived", "sex", "pclass"]

for n in num_for_box:
    for c in cat_for_box:
        sns.boxplot(x = df[c], y = df[n])
        plt.title(f"{c} vs {n}")
        plt.xlabel(c)
        plt.ylabel(n)
        showlayout()

# %% [markdown]
# **Grouped Statistics**

# %%
avg_survival = df_nums.groupby("survived_label")["age"].mean()
avg_survival
# or

# df_nums.groupby("survived_label").mean()
# Out:
# survived_label
# No     30.626179
# Yes    28.343690
# Name: age, dtype: float64

# %% [markdown]
# **Crosstab Categorical Features**

# %%
# This function will show the frequency distribution of the combinations of values between these two columns, which can be helpful for analyzing relationships between categorical variables.

pd.crosstab(df_nums["pclass"], df_nums["survived_label"])
# Out:
# survived_label   No  Yes
# pclass
# 1                64  122
# 2                90   83
# 3               270   85

# %%
sns.countplot(x=df_nums["pclass"], hue=df_nums["survived_label"], palette="cool")
plt.title("Pclass vs Survived Label")
plt.xlabel("Pclass")
plt.ylabel("Count")
showlayout()

# %% [markdown]
# ## Plots

# %% [markdown]
# **Multivariate Analysis**
# - Pairplot
# - Correlation Heatmap
# - Cluster Map
# - Interaction & Sub Group Pattern Discovery

# %%
df_nums["survived_label"].map({"No":0, "Yes":1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: survived_label, Length: 714, dtype: int64

# %%
pairplot_cols = num_cols + ["survived_label"]

df_pair = df_nums[pairplot_cols].dropna()
sns.pairplot(df_pair, hue="survived_label")
showlayout()

# %%
sns.scatterplot(data=df_nums, x=df_nums["age"], y=df_nums["fare"], hue="survived_label")
# plt.axhline(y=100, color="red", alpha = .8, linewidth = 1.2)
showlayout()

# %%
sns.scatterplot(data=df_nums, x=df_nums["age"], y=df_nums["fare"], style=df["sex"], hue="survived_label")
showlayout()

# %% [markdown]
# **Correlation Heatmap**

# %%
df[num_cols].head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
sns.heatmap(df_nums.corr(numeric_only = True), cmap="coolwarm", annot = True)
plt.title("Numerical Datapoint Correlation")
showlayout()

# %% [markdown]
# **Cluster Heatmap**

# %%
sns.clustermap(df_nums.corr(numeric_only=True), figsize=(9,5), annot=True, cmap="coolwarm")

# %% [markdown]
# ### Interaction and Sub-Group Patterns

# %%
sns.scatterplot(x=df["age"], y=df["fare"], hue= df_nums["survived_label"])
plt.title("Age : Fare by Survival")
showlayout()

# %%
df_nums
# Out:
#      survived  pclass   age  sibsp  parch     fare survived_label
# 0           0       3  22.0      1      0   7.2500             No
# 1           1       1  38.0      1      0  71.2833            Yes
# 2           1       3  26.0      0      0   7.9250            Yes
# 3           1       1  35.0      1      0  53.1000            Yes
# 4           0       3  35.0      0      0   8.0500             No
# ..        ...     ...   ...    ...    ...      ...            ...
# 885         0       3  39.0      0      5  29.1250             No
# 886         0       2  27.0      0      0  13.0000             No
# 887         1       1  19.0      0      0  30.0000            Yes
# 889         1       1  26.0      0      0  30.0000            Yes
# 890         0       3  32.0      0      0   7.7500             No
#
# [714 rows x 7 columns]

# %%
sns.scatterplot(x=df["pclass"], y=df["fare"], hue=df_nums["survived_label"])
plt.title("Pclass vs Fare by Survival")
showlayout()
