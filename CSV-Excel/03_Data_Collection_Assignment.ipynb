# %%
# %pip install -q kagglehub

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("API_KEY")

# link: https://www.kaggle.com/datasets/alessandrolobello/the-ultimate-earthquake-dataset-from-1990-2023

# %%
import pandas as pd
import kagglehub
import shutil
import warnings

warnings.filterwarnings("ignore")

# Download latest version
# path = kagglehub.dataset_download("https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database?utm_source=chatgpt.com")
# path = kagglehub.dataset_download("uciml/pima-indians-diabetes-database")

# df_diabetes = pd.read_csv("diabetes.csv")
# print("Path to dataset files:", path)

# %%
# Copy dataset from source directory to destination directory 

# source_path = r"C:\Users\Benny\.cache\kagglehub\datasets\uciml\pima-indians-diabetes-database\versions\1"
source_path = r"C:\Users\Benny\Machine-Learning-Bootcamp\CSV-Excel"
destination_path = r"C:\Users\Benny\Machine-Learning-Bootcamp\CSV-Excel\Datasets" 

shutil.copytree(source_path, destination_path,dirs_exist_ok = True)
# Out:
# 'C:\\Users\\Benny\\Machine-Learning-Bootcamp\\CSV-Excel\\Datasets'

# %%
#  Review the files in the directory
files = os.listdir(destination_path)
print(files)

# Create full path to the CSV file
file_path = os.path.join(destination_path, "insurance.csv")
print(file_path)
# Out:
# ['01_Project_CSV_Excel_Parquet.ipynb', '02_Project_Kaggle.ipynb', '03_Data_Collection_Assignment.ipynb', 'Datasets', 'diabetes.csv', 'Eartquakes-1990-2023.csv', 'insurance.csv', 'titanic.csv', 'titanic.parquet', 'titanic.xlsx', 'titanic_tab.csv']
# C:\Users\Benny\Machine-Learning-Bootcamp\CSV-Excel\Datasets\insurance.csv

# %% [markdown]
# ### Load the dataset from a CSV file using Pandas

# %%
# Load dataset into a DataFrame
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ### Load the data back from the database into Pandas

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgresql://postgres:Singlebouya321%40@localhost:5432/MLPractice"

# %%
# Load the data back from the database into Pandas

new_engine = create_engine(connection_string)

database = pd.read_sql(
    sql="select * from datasets.insurance",
    con = new_engine
)

# %%
# Verify the shape and columns after loading from the database

database.shape
# Out:
# (1338, 7)

# %%
# Save the loaded data as an Excel file

database.to_excel("new_insurance.xlsx", index=False)

# Save the loaded data as a Parquet file

database.to_parquet("new_insurance.parquet", index=False)

# %% [markdown]
# ### Optional challenges:

# %%
# Load a dataset directly from Kaggle

import kagglehub

# Download latest version
path = kagglehub.dataset_download("yashdevladdha/uber-ride-analytics-dashboard")

print(os.listdir(path))

file_path = os.path.join(path, "ncr_ride_bookings.csv")

kag_df = pd.read_csv(file_path)
# Out:
# ['Dasboard.gif', 'ncr_ride_bookings.csv', 'Uber.pbix']

# %%
# Load a dataset from the UCI Machine Learning Repository

# %pip install -q ucimlrepo

from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
  
# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets 
  
# metadata 
print(bank_marketing.metadata) 
  
# variable information 
print(bank_marketing.variables)
# Out:
# WARNING: Ignoring invalid distribution ~upyterlab (c:\Users\Benny\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (c:\Users\Benny\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (c:\Users\Benny\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# Compare shapes and columns across all data sources

print(f"CSV Datasource: {df.shape}")
print(f"DB Datasource: {database.shape}")
print(f"Kaggle Datasource: {kag_df.shape}")
print(f"UCI Datasource X: {X.shape}")
print(f"UCI Datasource y: {y.shape}")
# Out:
# CSV Datasource: (1338, 7)
# DB Datasource: (1338, 7)
# Kaggle Datasource: (150000, 21)
# UCI Datasource X: (45211, 16)
# UCI Datasource y: (45211, 1)
